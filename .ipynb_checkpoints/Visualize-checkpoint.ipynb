# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io
from glob import glob
from PIL import Image
from torchvision.transforms.functional import to_tensor
import skimage.io as io
import random

# %%
path = "/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/17/pifpafSample.pt"

x = torch.load(path)
print(x.shape)
# Out:
# torch.Size([1, 17, 5, 55, 81])

# %%
part_index = 0

body_part = x[0,part_index, 0, :,:]

print(body_part.shape)
# Out:
# torch.Size([55, 81])

# %%
#unrefined heatmaps

plt.imshow(body_part)

# %%
img = '/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/old/sample.jpg'
pil_img =  Image.open(img)

plt.imshow(pil_img)
print(pil_img.size)
# Out:
# (956, 600)

# %%
hr_hm = '/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_0/sample.npy'
y = np.load(hr_hm)

y.shape
# Out:
# (609, 961)

# %%
# torchvision.utils.save_image(torch.tensor(y), "wat_visualization.png", normalize=True)

# %%
names = [
    "nose",
    "left_eye",
    "right_eye",
    "left_ear",
    "right_ear",
    "left_shoulder",
    "right_shoulder",
    "left_elbow",
    "right_elbow",
    "left_wrist",
    "right_wrist",
    "left_hip",
    "right_hip",
    "left_knee",
    "right_knee",
    "left_ankle",
    "right_ankle",
]

# %%
#Visualize HR_PIF Heatmaps
base = "/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/old/sample.jpg"

hr_hm = '/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_*/sample.npy'
files = glob(hr_hm)
files.sort()

# for f,n in zip(files,names):
#     y = np.load(f)
#     h2,w2 = y.shape
#     break
red = np.array([1, 0,0 ]).reshape(1, 1, 3)

for f,n in zip(files,names):
    print(f"Keypoint: {n}")
    print(f"HM path: {f}")
    
    y = np.load(f)
    h2,w2 = y.shape
    
    #resize to match size of both imgs
    b = Image.open(base).resize((w2, h2), Image.BICUBIC)
    b = to_tensor(b).permute(1,2,0).numpy()
    
    
#     h1,w1,c = b.shape
    
#     b = b.mean(axis=2)[:,:,None]
    red_y = red * y[:,:, None]

#     b = to_tensor(b).mean(dim=0).numpy()
#     h = min(h1,h2)
#     w = min(w1,w2)
    
#     print(n, f)
    
#     v = 0.5 * b + 0.5 * red * b * y[:,:, None]
    
    v = 0.8 * red_y + 0.2 * b
    v = (v - v.min()) / (v.max()-v.min())
    io.imshow(v)

    
#     io.imshow(0.7*y+0.3*b)
#     io.imshow(0.7*y[:h,:w]+0.3*b[:h,:w])
    
    io.show()

#     print(v.shape)
#     print('-'*114)
# Out:
# Keypoint: nose
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_0/sample.npy
# Keypoint: left_eye
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_1/sample.npy
# Keypoint: right_eye
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_10/sample.npy
# Keypoint: left_ear
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_11/sample.npy
# Keypoint: right_ear
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_12/sample.npy
# Keypoint: left_shoulder
# HM path: /home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/cache_pifpaf_results/field_13/sample.npy
# Keypoint: right_shoulder
# ...

# %%
b.shape
# Out:
# (609, 961, 3)

# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
dataDir='/home/hestia/Documents/Experiments/Test/Implement/openpifpaf/openpifpaf/data-mscoco'
dataType='train2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)

# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=9.86s)
# creating index...
# index created!

# %%
filterClasses = ['person']

catIds = coco.getCatIds(catNms=filterClasses)

imgIds = coco.getImgIds(catIds=catIds)

print("Number of images containing all the  classes:", len(imgIds))
# Out:
# Number of images containing all the  classes: 64115

# %%
ims = []

for i in range (10):
    ims.append(coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0])
    print(ims[i]['file_name'])
# Out:
# 000000240889.jpg
# 000000320832.jpg
# 000000133002.jpg
# 000000335696.jpg
# 000000280955.jpg
# 000000248924.jpg
# 000000218556.jpg
# 000000187435.jpg
# 000000577118.jpg
# 000000114634.jpg
